# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, recall_score, precision_score
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import json
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LogisticRegression
#from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier

# %%
def load_data(file):
    df = pd.read_csv(os.path.join("data", file))
    return df

df = load_data("train.csv")

# %%
new_df = load_data("test_data.csv")

# %%
new_df = new_df.rename(columns={"Outcome": "success"})

# %%
def clean(df):


    df = df.drop(df[df['station'].isin(["leicestershire",'humberside', 'lancashire','metropolitan','west-midlands'])].index)
    
    df['Part of a policing operation'] = df['Part of a policing operation'].fillna(False)
    df['Part of a policing operation'] = df['Part of a policing operation'].astype(bool)

    df['Outcome linked to object of search'] = df['Outcome linked to object of search'].fillna(False)

    df['Legislation'] = df['Legislation'].fillna('unknown')
    
    df.loc[df['Outcome'] == 'A no further action disposal', 'Outcome linked to object of search'] = False
    
    success_outcomes = ['Community resolution', 'Khat or Cannabis warning', 'Caution (simple or conditional)', 
                    'Arrest', 'Penalty Notice for Disorder', 'Summons / charged by post', 
                    'Suspect arrested', 'Suspect summoned to court']

    # create a new column called "success" with 1 if the outcome is in the list of successful outcomes, 0 otherwise
    df['success'] = df.apply(lambda x: True if x['Outcome'] in success_outcomes and x['Outcome linked to object of search'] == True else False, axis=1)

    df=df[['observation_id', 'Type', 'Date', 'Part of a policing operation',
       'Latitude', 'Longitude', 'Gender', 'Age range',
       'Officer-defined ethnicity', 'Legislation', 'Object of search',
       'station', "success"]]
    
    #df=df.dropna()
    return df

df_new = clean(df)

# %%
new_df=new_df.drop(columns='Predicted outcome', axis=1)

# %%
combined_df = pd.concat([new_df, df_new], axis=0, ignore_index=True)

# %%
class DateTransformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X = X.copy()
        X['Date'] = pd.to_datetime(X['Date'])
        X['Hour'] = X['Date'].dt.hour
        X['Month'] = X['Date'].dt.month
        X['Day'] = X['Date'].dt.day
        X['DayOfWeek'] = X['Date'].dt.weekday
        X=X.drop(columns = "Date", axis=1)
        
        return X[['Hour','Month', 'Day', 'DayOfWeek']]

    def get_feature_names_out(self):
        return [('Date', 'Hour'), ('Date', 'Month'), ('Date', 'Day'),('Date', 'DayOfWeek')]

# %%
features = ['Part of a policing operation','Legislation', 'Object of search','Date','station','Gender', 'Age range','Officer-defined ethnicity']
target = 'success'

# Split data into training and testing sets
X_train = combined_df[features]
y_train =  combined_df[target]

categorical_columns = ['Legislation', 'Object of search','Part of a policing operation','Date',"Age range","Gender",'Officer-defined ethnicity','station']
feat_columns = ['Date']

categorical_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
        ('onehot', OneHotEncoder(handle_unknown='ignore')),
    ])

preprocessor = ColumnTransformer(
    transformers=[
       ('date_transformer', DateTransformer(), feat_columns),
        ('categorical_transformers', categorical_transformer, categorical_columns),
    ])


preprocessor.fit(X_train)

pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                           #("classifer",    LGBMClassifier(n_estimators=100, max_depth = 3,learning_rate=0.1,class_weight="balanced", random_state=42, n_jobs=-1))
                           ("classifer",LogisticRegression(C=1, class_weight='balanced', n_jobs=-1, random_state=42))
                        ])

# Fit model on training data
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('date_transformer',
#                                                   DateTransformer(), ['Date']),
#                                                  ('categorical_transformers',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Legislation',
#                                                    'Object of search',
#                                                    'Part of a policing '
#                                                    'operation',
#                                                    'Date', 'Age range',
#                                                    'Gender',
#                                                    'Officer-defined ethnicity',
#                                                    'station'])])),
#                 ('classifer',
#                  LogisticRegression(C=1, class_weight='balanced', n_jobs=-1,
#                                     random_state=42))])

# %%
import pickle
import gzip

columns = list(X_train.columns)

# Serialize the list to a JSON file in the temporary directory
filepath = os.path.join('columns.json')

with open(filepath, 'w') as f:
    json.dump(columns, f)
    
    
dtypes = X_train.dtypes

filepath = os.path.join('dtypes.pickle')

with open(filepath, 'wb') as f:
    pickle.dump(dtypes, f)
    

    
filepath = os.path.join('pipeline.pickle')

with open(filepath, 'wb') as f:
    pickle.dump(pipeline, f)
# Out:
# /home/francisco/.virtualenvs/slu01/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Test run on the api

# %%
import pandas as pd

# Read the JSON files
df1 = pd.read_json('newdata/subset_moment_1.json')
df2 = pd.read_json('newdata/subset_moment_2.json')

# %%
# Create a new DataFrame from the 'data' column
new_df1 = pd.json_normalize(df1['data'])
new_df2 = pd.json_normalize(df2['data'])

# %%
# Set the base URL of your API
import requests
import pandas as pd
import time

APP_NAME = 'railcap-production.up.railway.app'
base_url = "https://{}/should_search/".format(APP_NAME)
# Test locally
#base_url = f"http://localhost:5000/should_search/"

# Define the columns to check for missing values
x=0
l=[]
for i, row in new_df1.iterrows():
    # Remove any columns with NaN values from the row
    row = row.dropna()

    # Convert the row to a dictionary
    row_dict = row.to_dict()
    print(row_dict)
    # Send a POST request to your API with the row data
    response = requests.post(base_url, json=row_dict)

    # Print the response status code and content for debugging purposes
    print(response.status_code)
    print(response.content)
    
    time.sleep(0.1)
    x+=1
    if x == 1000 :
        break
# Out:
# /home/francisco/.virtualenvs/slu01/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# {'observation_id': 'ae3e0d41-7c19-4ecc-8d32-767e3bfdb52a', 'Type': 'Person search', 'Date': '2022-01-01T00:35:00+00:00', 'Part of a policing operation': False, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'Black', 'Legislation': 'Criminal Justice Act 1988 (section 139B)', 'Object of search': 'Offensive weapons', 'station': 'nottinghamshire'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': '1b553034-0b2b-435b-b614-ce0a6c8d5f83', 'Type': 'Person search', 'Date': '2022-01-01T01:05:06+00:00', 'Part of a policing operation': False, 'Latitude': 52.574809, 'Longitude': -0.241137, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'cambridgeshire'}
# 405
# b'{\n  "error": "Observation ID: \\"1b553034-0b2b-435b-b614-ce0a6c8d5f83\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '36ec1461-5190-496c-b82f-95c7ae9ff59f', 'Type': 'Person search', 'Date': '2022-01-01T01:14:23+00:00', 'Latitude': 51.506255, 'Longitude': -0.074901, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"36ec1461-5190-496c-b82f-95c7ae9ff59f\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': '6f38f480-c0a0-45fb-81cd-ab56f0bb6351', 'Type': 'Person search', 'Date': '2022-01-01T01:20:32+00:00', 'Latitude': 51.506255, 'Longitude': -0.074901, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"6f38f480-c0a0-45fb-81cd-ab56f0bb6351\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': 'e7ab1073-5193-4ec6-aa07-efb0bc97acbb', 'Type': 'Person search', 'Date': '2022-01-01T01:28:56+00:00', 'Latitude': 51.506255, 'Longitude': -0.074901, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"e7ab1073-5193-4ec6-aa07-efb0bc97acbb\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': 'ec925f54-c0dd-4527-b941-fcb87a12ec1c', 'Type': 'Person search', 'Date': '2022-01-01T02:16:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.71235, 'Longitude': -3.553934, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"ec925f54-c0dd-4527-b941-fcb87a12ec1c\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': '8edce445-67c9-4a5f-b616-b3c35317a2e9', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T02:42:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.623704, 'Longitude': -4.677945, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"8edce445-67c9-4a5f-b616-b3c35317a2e9\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '34b142db-63a2-42ee-89a4-e553051ab933', 'Type': 'Person search', 'Date': '2022-01-01T02:49:39+00:00', 'Latitude': 51.51768, 'Longitude': -0.078484, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': '8bc83a92-026d-445b-9daa-de2f9862c08f', 'Type': 'Person search', 'Date': '2022-01-01T02:55:00+00:00', 'Part of a policing operation': False, 'Gender': 'Female', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"8bc83a92-026d-445b-9daa-de2f9862c08f\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'ba91d868-9056-4402-b36e-9e71c90caec3', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T03:08:37+00:00', 'Latitude': 52.312706, 'Longitude': -0.225271, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'cambridgeshire'}
# 405
# b'{\n  "error": "Observation ID: \\"ba91d868-9056-4402-b36e-9e71c90caec3\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'af500e60-b8b2-404c-b1e5-25ce9b00556b', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T03:31:00+00:00', 'Latitude': 54.774409, 'Longitude': -1.5414789999999998, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Article for use in theft', 'station': 'durham'}
# 405
# b'{\n  "error": "Observation ID: \\"af500e60-b8b2-404c-b1e5-25ce9b00556b\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '8424fbd7-e7ca-458f-baf4-97bdf36b3b3a', 'Type': 'Person search', 'Date': '2022-01-01T04:10:00+00:00', 'Part of a policing operation': False, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'nottinghamshire'}
# 405
# b'{\n  "error": "Observation ID: \\"8424fbd7-e7ca-458f-baf4-97bdf36b3b3a\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'e115f1e1-f841-49d2-bbd9-b1556c649cef', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T04:18:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.625847, 'Longitude': -3.546839, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"e115f1e1-f841-49d2-bbd9-b1556c649cef\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'ba106e8c-fb22-42de-a80d-9b0564964c75', 'Type': 'Person search', 'Date': '2022-01-01T04:28:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.625847, 'Longitude': -3.546839, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"ba106e8c-fb22-42de-a80d-9b0564964c75\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '278a05ef-a3d9-42e4-b0ea-65fac9c5b4fd', 'Type': 'Person search', 'Date': '2022-01-01T04:29:00+00:00', 'Part of a policing operation': True, 'Latitude': 50.625847, 'Longitude': -3.546839, 'Gender': 'Female', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"278a05ef-a3d9-42e4-b0ea-65fac9c5b4fd\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '63e10559-6625-47ae-8cd6-1a3cafc45012', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T05:00:00+00:00', 'Part of a policing operation': False, 'Latitude': 52.005702, 'Longitude': -0.429307, 'Gender': 'Female', 'Age range': '25-34', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"63e10559-6625-47ae-8cd6-1a3cafc45012\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '9e8783a9-8377-448f-8882-d4b2f352187a', 'Type': 'Person search', 'Date': '2022-01-01T05:16:47+00:00', 'Latitude': 51.506255, 'Longitude': -0.074901, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"9e8783a9-8377-448f-8882-d4b2f352187a\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': '5f10c933-9c8b-4f9e-872c-c807b41a75c2', 'Type': 'Person search', 'Date': '2022-01-01T05:21:31+00:00', 'Latitude': 52.536892, 'Longitude': -0.26474000000000003, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'Other', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'cambridgeshire'}
# 405
# b'{\n  "error": "Observation ID: \\"5f10c933-9c8b-4f9e-872c-c807b41a75c2\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '1e06ef0a-35e0-48af-b524-1eeeb5029b72', 'Type': 'Person search', 'Date': '2022-01-01T05:41:27+00:00', 'Latitude': 51.518091, 'Longitude': -0.078308, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"1e06ef0a-35e0-48af-b524-1eeeb5029b72\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'b5882d71-b142-4ff4-a387-62de28d6bead', 'Type': 'Person search', 'Date': '2022-01-01T05:50:23+00:00', 'Latitude': 51.518091, 'Longitude': -0.078308, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"b5882d71-b142-4ff4-a387-62de28d6bead\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '9e750573-93a5-486a-8507-66e24464e27f', 'Type': 'Person search', 'Date': '2022-01-01T06:29:20+00:00', 'Latitude': 51.516814, 'Longitude': -0.08162000000000001, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'Black', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"9e750573-93a5-486a-8507-66e24464e27f\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'b0453ec3-ade4-4bc3-983f-bd7be6fc498b', 'Type': 'Person search', 'Date': '2022-01-01T06:45:26+00:00', 'Latitude': 51.516814, 'Longitude': -0.08162000000000001, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'Black', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"b0453ec3-ade4-4bc3-983f-bd7be6fc498b\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'ef453f2b-b3cb-4dc6-8503-0ebaf84c72ad', 'Type': 'Person search', 'Date': '2022-01-01T07:27:56+00:00', 'Latitude': 51.516814, 'Longitude': -0.08162000000000001, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 405
# b'{\n  "error": "Observation ID: \\"ef453f2b-b3cb-4dc6-8503-0ebaf84c72ad\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'c528cf17-8d8d-4271-864d-7f53219201bc', 'Type': 'Person search', 'Date': '2022-01-01T07:34:03+00:00', 'Latitude': 51.506255, 'Longitude': -0.074901, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": false\n}\n'
# {'observation_id': '7fe5aa01-a3fd-400b-9216-817c6accb5c2', 'Type': 'Person search', 'Date': '2022-01-01T13:13:00+00:00', 'Part of a policing operation': False, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'nottinghamshire'}
# 405
# b'{\n  "error": "Observation ID: \\"7fe5aa01-a3fd-400b-9216-817c6accb5c2\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '818e267b-99af-440f-8e99-1dfafc285618', 'Type': 'Person search', 'Date': '2022-01-01T13:35:00+00:00', 'Part of a policing operation': False, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'nottinghamshire'}
# 405
# b'{\n  "error": "Observation ID: \\"818e267b-99af-440f-8e99-1dfafc285618\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'a4c0171b-7c31-42d1-b83d-2936c7757f05', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T15:45:00+00:00', 'Part of a policing operation': False, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"a4c0171b-7c31-42d1-b83d-2936c7757f05\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '804a0d41-fd29-4d60-890e-9f930501301e', 'Type': 'Person search', 'Date': '2022-01-01T16:43:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.72501, 'Longitude': -3.524855, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"804a0d41-fd29-4d60-890e-9f930501301e\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '3ba49efb-19b9-4d23-bdda-99fb86d7cba4', 'Type': 'Person search', 'Date': '2022-01-01T18:55:00+00:00', 'Part of a policing operation': False, 'Latitude': 51.875599, 'Longitude': -0.43781000000000003, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"3ba49efb-19b9-4d23-bdda-99fb86d7cba4\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': '584dc8b0-0ab3-426d-834c-b9e908220243', 'Type': 'Person and Vehicle search', 'Date': '2022-01-01T21:00:00+00:00', 'Part of a policing operation': False, 'Latitude': 51.89663, 'Longitude': -0.44728399999999996, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"584dc8b0-0ab3-426d-834c-b9e908220243\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '971771d6-cb1d-4cc6-ace0-22793e20c596', 'Type': 'Person search', 'Date': '2022-01-01T21:09:00+00:00', 'Part of a policing operation': False, 'Latitude': 52.107923, 'Longitude': -0.501636, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"971771d6-cb1d-4cc6-ace0-22793e20c596\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': '1c6db03d-fd91-49f9-be1b-15885c095a47', 'Type': 'Person search', 'Date': '2022-01-01T21:15:00+00:00', 'Part of a policing operation': False, 'Latitude': 51.89663, 'Longitude': -0.44728399999999996, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"1c6db03d-fd91-49f9-be1b-15885c095a47\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'c948d19f-00fc-443c-8bc8-004692b969c6', 'Type': 'Person search', 'Date': '2022-01-01T21:20:00+00:00', 'Part of a policing operation': False, 'Latitude': 51.902864, 'Longitude': -0.517931, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"c948d19f-00fc-443c-8bc8-004692b969c6\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '66b0867a-d116-4309-95a3-b4a994325c8a', 'Type': 'Person search', 'Date': '2022-01-01T23:54:00+00:00', 'Part of a policing operation': False, 'Latitude': 51.879133, 'Longitude': -0.423014, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'Asian', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'bedfordshire'}
# 405
# b'{\n  "error": "Observation ID: \\"66b0867a-d116-4309-95a3-b4a994325c8a\\" already exists",\n  "outcome": false\n}\n'
# {'observation_id': '6b3370a4-0c58-4130-a951-c25b6a6d54a8', 'Type': 'Person and Vehicle search', 'Date': '2022-01-02T01:10:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.128305, 'Longitude': -5.541647, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"6b3370a4-0c58-4130-a951-c25b6a6d54a8\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '06f89c2a-408f-4fc4-858b-a9563ff5b445', 'Type': 'Person search', 'Date': '2022-01-02T01:10:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.128305, 'Longitude': -5.541647, 'Gender': 'Female', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 405
# b'{\n  "error": "Observation ID: \\"06f89c2a-408f-4fc4-858b-a9563ff5b445\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': 'c680822c-4619-460a-acc7-75c18f4f7bc2', 'Type': 'Person and Vehicle search', 'Date': '2022-01-02T01:30:00+00:00', 'Latitude': 54.65702, 'Longitude': -1.676693, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'durham'}
# 405
# b'{\n  "error": "Observation ID: \\"c680822c-4619-460a-acc7-75c18f4f7bc2\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id': '2c76c3fb-7683-4e7d-b1a0-b31e8b0a125e', 'Type': 'Person and Vehicle search', 'Date': '2022-01-02T02:02:00+00:00', 'Part of a policing operation': False, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'nottinghamshire'}
# 405
# b'{\n  "error": "Observation ID: \\"2c76c3fb-7683-4e7d-b1a0-b31e8b0a125e\\" already exists",\n  "outcome": true\n}\n'
# {'observation_id':
 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Stolen goods', 'station': 'durham'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'f01bc84f-260f-4cc3-a077-fb5191e253d3', 'Type': 'Person search', 'Date': '2022-01-06T04:43:00+00:00', 'Latitude': 54.748187, 'Longitude': -2.017632, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Stolen goods', 'station': 'durham'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'f787b261-488f-4353-9697-987bf643d5b8', 'Type': 'Person search', 'Date': '2022-01-06T05:36:25+00:00', 'Latitude': 51.508257, 'Longitude': -0.104503, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'Black', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'ec391408-d4c1-4600-8d7c-0bc74306c1b5', 'Type': 'Person search', 'Date': '2022-01-06T06:36:14+00:00', 'Latitude': 51.512598, 'Longitude': -0.084967, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'Other', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Article for use in theft', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'b0199c52-3810-4b14-b2ff-3e4a745a57d5', 'Type': 'Person search', 'Date': '2022-01-06T06:37:58+00:00', 'Latitude': 51.512598, 'Longitude': -0.084967, 'Gender': 'Male', 'Age range': 'over 34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Article for use in theft', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'fb89c537-6463-4011-8f98-17a44f53f68d', 'Type': 'Person search', 'Date': '2022-01-06T07:18:24+00:00', 'Latitude': 51.513627, 'Longitude': -0.076435, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Article for use in theft', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'd61e50a4-d4d1-4be0-a6a6-d434c3819046', 'Type': 'Person search', 'Date': '2022-01-06T07:30:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.47014, 'Longitude': -3.540186, 'Gender': 'Male', 'Age range': '10-17', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Offensive weapons', 'station': 'devon-and-cornwall'}
# 200
# b'{\n  "outcome": false\n}\n'
# {'observation_id': 'd33eb781-af3b-4b18-99b7-a478ba5a0ede', 'Type': 'Person search', 'Date': '2022-01-06T08:44:44+00:00', 'Latitude': 51.516814, 'Longitude': -0.08162000000000001, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'city-of-london'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': '0e594191-a556-4d5d-868e-756047f8d51b', 'Type': 'Person search', 'Date': '2022-01-06T11:20:00+00:00', 'Part of a policing operation': False, 'Latitude': 50.372756, 'Longitude': -4.136327, 'Gender': 'Male', 'Age range': '18-24', 'Officer-defined ethnicity': 'White', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'devon-and-cornwall'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': '0aac1b1d-bcf3-4804-926d-7f12d37eafeb', 'Type': 'Person search', 'Date': '2022-01-06T11:30:00+00:00', 'Part of a policing operation': True, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'Black', 'Legislation': 'Misuse of Drugs Act 1971 (section 23)', 'Object of search': 'Controlled drugs', 'station': 'nottinghamshire'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': 'c8fc3f10-7455-43ae-a830-4b7bb6084b60', 'Type': 'Person search', 'Date': '2022-01-06T12:44:00+00:00', 'Latitude': 52.180785, 'Longitude': 0.124971, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Article for use in theft', 'station': 'cambridgeshire'}
# 200
# b'{\n  "outcome": true\n}\n'
# {'observation_id': '9d7acb30-d451-4239-8242-16c21aefec56', 'Type': 'Person search', 'Date': '2022-01-06T12:56:14+00:00', 'Latitude': 52.180785, 'Longitude': 0.124971, 'Gender': 'Male', 'Age range': '25-34', 'Officer-defined ethnicity': 'White', 'Legislation': 'Police and Criminal Evidence Act 1984 (section 1)', 'Object of search': 'Article for use in theft', 'station': 'cambridgeshire'}

# %%
# Set the base URL of your API
import requests
import pandas as pd
import time

APP_NAME = 'railcap-production.up.railway.app'
base_url = "https://{}/should_search/".format(APP_NAME)


# Define the columns to check for missing values
x=0
l=[]
for i, row in new_df1.iterrows():
    # Remove any columns with NaN values from the row
    row = row.dropna()

    # Convert the row to a dictionary
    row_dict = row.to_dict()
    
    # Send a POST request to your API with the row data
    response = requests.post(base_url, json=row_dict)

    # Print the response status code and content for debugging purposes
    print(response.status_code)
    print(response.content)
    
    time.sleep(0.1)
    x+=1
    if x == 1 :
        break
# Out:
# 503
# b'<!DOCTYPE html>\n<html>\n  <head>\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <meta charset="utf-8" />\n    <title>Server Error</title>\n    <style media="screen">\n      :root {\n        --bg: hsl(250, 24%, 9%);\n        --fg: hsl(0, 0%, 100%);\n        --pink: hsl(270, 60%, 52%);\n      }\n\n      html,\n      body {\n        margin: 0;\n        padding: 0;\n        height: 100%;\n        overflow: hidden;\n        background-color: var(--bg);\n        color: var(--fg);\n        font-family: -apple-system, BlinkMacSystemFont, Segoe UI, Roboto,\n          Oxygen-Sans, Ubuntu, Cantarell, Helvetica Neue, sans-serif,\n          Apple Color Emoji, Segoe UI Emoji, Segoe UI Symbol;\n      }\n\n      main {\n        display: flex;\n        flex-direction: column;\n        align-items: center;\n        justify-content: center;\n        padding: 16px;\n        height: 100%;\n      }\n\n      .logo {\n        width: 160px;\n        height: 160px;\n      }\n\n      main h1 {\n        font-size: 32px;\n        font-weight: 700;\n      }\n\n      main a {\n        appearance: none;\n        display: flex;\n        align-items: center;\n        text-decoration: none;\n        color: var(--fg);\n        background-color: var(--pink);\n        padding: 12px 24px;\n        border-radius: 6px;\n      }\n\n      main a:hover {\n        background-color: hsl(270, 60%, 42%);\n      }\n\n      h1 {\n        display: none;\n        margin-top: 2rem;\n        margin-bottom: 2rem;\n      }\n\n      .error-503 {\n        display: block;\n      }\n    </style>\n  </head>\n\n  <body>\n    <main>\n      <svg\n        class="logo"\n        xmlns="http://www.w3.org/2000/svg"\n        viewBox="0 0 1024 1024"\n        fill="none"\n      >\n        <path\n          d="M4.756 438.175A520.713 520.713 0 0 0 0 489.735h777.799c-2.716-5.306-6.365-10.09-10.045-14.772-132.97-171.791-204.498-156.896-306.819-161.26-34.114-1.403-57.249-1.967-193.037-1.967-72.677 0-151.688.185-228.628.39-9.96 26.884-19.566 52.942-24.243 74.14h398.571v51.909H4.756ZM783.93 541.696H.399c.82 13.851 2.112 27.517 3.978 40.999h723.39c32.248 0 50.299-18.297 56.162-40.999ZM45.017 724.306S164.941 1018.77 511.46 1024c207.112 0 385.071-123.006 465.907-299.694H45.017Z"\n          fill="#fff"\n        />\n        <path\n          d="M511.454 0C319.953 0 153.311 105.16 65.31 260.612c68.771-.144 202.704-.226 202.704-.226h.031v-.051c158.309 0 164.193.707 195.118 1.998l19.149.706c66.7 2.224 148.683 9.384 213.19 58.19 35.015 26.471 85.571 84.896 115.708 126.52 27.861 38.499 35.876 82.756 16.933 125.158-17.436 38.97-54.952 62.215-100.383 62.215H16.69s4.233 17.944 10.58 37.751h970.632A510.385 510.385 0 0 0 1024 512.218C1024.01 229.355 794.532 0 511.454 0Z"\n          fill="#fff"\n        />\n      </svg>\n\n      <h1 class="error-404">Nothing here... yet</h1>\n      <h1 class="error-503">Application failed to respond</h1>\n\n      <a href="https://railway.app" target="_blank"> Go to Railway </a>\n    </main>\n  </body>\n</html>\n'
